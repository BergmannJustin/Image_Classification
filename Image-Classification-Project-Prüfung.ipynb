# %% [markdown]
# <a href="https://colab.research.google.com/github/BergmannJustin/Image_Classification_Pr-fung/blob/main/Image-Classification-Project-Pr%C3%BCfung.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Libraries

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# #Loading CIFAR-100 dataset

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 3s 0us/step

# %%
class_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle',
    'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle',
    'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard',
    'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain',
    'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree',
    'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose', 'sea',
    'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower',
    'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout', 'tulip', 'turtle',
    'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'
]

plt.figure(figsize=(10, 5))
start_index = 20  # Startindex für die Auswahl der Bilder
num_images = 10   # Anzahl der Bilder, die angezeigt werden sollen

for i in range(start_index, start_index + num_images):
    plt.subplot(2, 5, i - start_index + 1)
    plt.imshow(x_train[i])
    plt.title(class_names[int(y_train[i][0])])
    plt.axis('off')

# %%
# Normalize pixel values to be between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# ###Adding augmentation

# %%
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

datagen.fit(x_train)

# %%
# Convert class vectors to binary class matrices
num_classes = 100
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# %% [markdown]
# #Building Model Architecture

# %%
def resnet_block(x, filters, kernel_size=3, stride=1, conv_shortcut=True):
    shortcut = x
    if conv_shortcut:
        shortcut = layers.Conv2D(filters, 1, strides=stride, padding='same')(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Conv2D(filters, kernel_size, strides=stride, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters, kernel_size, padding='same')(x)
    x = layers.BatchNormalization()(x)

    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

def modifyNet(input_shape, num_classes=100, num_blocks_list=[2, 2, 2, 2], dropout_rate=0.5):
    inputs = tf.keras.Input(shape=input_shape)

    x = layers.Conv2D(128, 3, strides=1, padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    # Adding Dropout layer after the first set of residual blocks
    x = layers.Dropout(dropout_rate)(x)

    for i, num_blocks in enumerate(num_blocks_list):
        for j in range(num_blocks):
            strides = 2 if i > 0 and j == 0 else 1
            x = resnet_block(x, 128 * 2**i, stride=strides)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, x)
    return model

# %%
input_shape = x_train.shape[1:]
model = modifyNet(input_shape, num_classes)

# %% [markdown]
# ###Compiling the model

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ###Displaing model summary

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  conv2d_25 (Conv2D)          (None, 32, 32, 128)          3584      ['input_2[0][0]']
#
#  batch_normalization_25 (Ba  (None, 32, 32, 128)          512       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  dropout_1 (Dropout)         (None, 32, 32, 128)          0         ['activation_17[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 32, 32, 128)          147584    ['dropout_1[0][0]']
#
#  batch_normalization_27 (Ba  (None, 32, 32, 128)          512       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 32, 32, 128)          147584    ['activation_18[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 32, 32, 128)          16512     ['dropout_1[0][0]']
#
#  batch_normalization_28 (Ba  (None, 32, 32, 128)          512       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 32, 32, 128)          512       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 32, 32, 128)          0         ['batch_normalization_28[0][0]
#                                                                     ',
#                                                                      'batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_19 (Activation)  (None, 32, 32, 128)          0         ['add_8[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 32, 32, 128)          147584    ['activation_19[0][0]']
#
#  batch_normalization_30 (Ba  (None, 32, 32, 128)          512       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 128)          147584    ['activation_20[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 32, 32, 128)          16512     ['activation_19[0][0]']
#
#  batch_normalization_31 (Ba  (None, 32, 32, 128)          512       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 32, 32, 128)          512       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 32, 32, 128)          0         ['batch_normalization_31[0][0]
#                                                                     ',
#                                                                      'batch_normalization_29[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 32, 32, 128)          0         ['add_9[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 16, 16, 256)          295168    ['activation_21[0][0]']
#
#  batch_normalization_33 (Ba  (None, 16, 16, 256)          1024      ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 16, 16, 256)          0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 16, 16, 256)          590080    ['activation_22[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 16, 16, 256)          33024     ['activation_21[0][0]']
#
#  batch_normalization_34 (Ba  (None, 16, 16, 256)          1024      ['conv2d_34[0][0]']
#  tchNormalization)
#
#  batch_normalization_32 (Ba  (None, 16, 16, 256)          1024      ['conv2d_32[0][0]']
#  tchNormalization)
#
#  add_10 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_34[0][0]
#                                                                     ',
#                                                                      'batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 16, 16, 256)          0         ['add_10[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 16, 16, 256)          590080    ['activation_23[0][0]']
#
#  batch_normalization_36 (Ba  (None, 16, 16, 256)          1024      ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 16, 16, 256)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 16, 16, 256)          590080    ['activation_24[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 16, 16, 256)          65792     ['activation_23[0][0]']
#
#  batch_normalization_37 (Ba  (None, 16, 16, 256)          1024      ['conv2d_37[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 16, 16, 256)          1024      ['conv2d_35[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_37[0][0]
#                                                                     ',
#                                                                      'batch_normalization_35[0][0]
#                                                                     ']
#
#  activation_25 (Activation)  (None, 16, 16, 256)          0         ['add_11[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 8, 8, 512)            1180160   ['activation_25[0][0]']
#
#  batch_normalization_39 (Ba  (None, 8, 8, 512)            2048      ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 8, 8, 512)            0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 8, 8, 512)            2359808   ['activation_26[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 8, 8, 512)            131584    ['activation_25[0][0]']
#
#  batch_normalization_40 (Ba  (None, 8, 8, 512)            2048      ['conv2d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 8, 8, 512)            2048      ['conv2d_38[0][0]']
#  tchNormalization)
#
#  add_12 (Add)                (None, 8, 8, 512)            0         ['batch_normalization_40[0][0]
#                                                                     ',
#                                                                      'batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_27 (Activation)  (None, 8, 8, 512)            0         ['add_12[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 8, 8, 512)            2359808   ['activation_27[0][0]']
#
#  batch_normalization_42 (Ba  (None, 8, 8, 512)            2048      ['conv2d_42[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 8, 8, 512)            0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 8, 8, 512)            2359808   ['activation_28[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 8, 8, 512)            262656    ['activation_27[0][0]']
#
#  batch_normalization_43 (Ba  (None, 8, 8, 512)            2048      ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 8, 8, 512)            2048      ['conv2d_41[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 8, 8, 512)            0         ['batch_normalization_43[0][0]
#                                                                     ',
#                                                                      'batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 8, 8, 512)            0         ['add_13[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 4, 4, 1024)           4719616   ['activation_29[0][0]']
#
#  batch_normalization_45 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 4, 4, 1024)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_46 (Conv2D)          (None, 4, 4, 1024)           9438208   ['activation_30[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 4, 4, 1024)           525312    ['activation_29[0][0]']
#
#  batch_normalization_46 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_46[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_44[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 4, 4, 1024)           0         ['batch_normalization_46[0][0]
#                                                                     ',
#                                                                      'batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_31 (Activation)  (None, 4, 4, 1024)           0         ['add_14[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 4, 4, 1024)           9438208   ['activation_31[0][0]']
#
#  batch_normalization_48 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_48[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 4, 4, 1024)           0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 4, 4, 1024)           9438208   ['activation_32[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 4, 4, 1024)           1049600   ['activation_31[0][0]']
#
#  batch_normalization_49 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_49[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_47[0][0]']
#  tchNormalization)
#
#  add_15 (Add)                (None, 4, 4, 1024)           0         ['batch_normalization_49[0][0]
#                                                                     ',
#                                                                      'batch_normalization_47[0][0]
#                                                                     ']
#
#  activation_33 (Activation)  (None, 4, 4, 1024)           0         ['add_15[0][0]']
#
#  global_average_pooling2d_1  (None, 1024)                 0         ['activation_33[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 100)                  102500    ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 46203236 (176.25 MB)
# Trainable params: 46179940 (176.16 MB)
# Non-trainable params: 23296 (91.00 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# #Training the model

# %%
epochs = 30
batch_size = 64
history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), epochs=epochs)
# Out:
# Epoch 1/30
# 782/782 [==============================] - 207s 231ms/step - loss: 3.9712 - accuracy: 0.0912
# Epoch 2/30
# 782/782 [==============================] - 180s 230ms/step - loss: 3.3281 - accuracy: 0.1833
# Epoch 3/30
# 782/782 [==============================] - 180s 230ms/step - loss: 2.8472 - accuracy: 0.2771
# Epoch 4/30
# 782/782 [==============================] - 180s 230ms/step - loss: 2.4755 - accuracy: 0.3534
# Epoch 5/30
# 782/782 [==============================] - 180s 230ms/step - loss: 2.1976 - accuracy: 0.4140
# Epoch 6/30
# 782/782 [==============================] - 180s 231ms/step - loss: 1.9761 - accuracy: 0.4622
# Epoch 7/30
# 782/782 [==============================] - 180s 230ms/step - loss: 1.7959 - accuracy: 0.5044
# Epoch 8/30
# 782/782 [==============================] - 180s 230ms/step - loss: 1.6433 - accuracy: 0.5396
# Epoch 9/30
# 782/782 [==============================] - 180s 230ms/step - loss: 1.5141 - accuracy: 0.5717
# Epoch 10/30
# 782/782 [==============================] - 180s 230ms/step - loss: 1.3997 - accuracy: 0.6025
# Epoch 11/30
# 782/782 [==============================] - 180s 230ms/step - loss: 1.3015 - accuracy: 0.6234
# Epoch 12/30
# 782/782 [==============================] - 180s 230ms/step - loss: 1.2014 - accuracy: 0.6507
# Epoch 13/30
# 782/782 [==============================] - 180s 230ms/step - loss: 1.1100 - accuracy: 0.6726
# Epoch 14/30
# 782/782 [==============================] - 179s 229ms/step - loss: 1.0259 - accuracy: 0.6949
# Epoch 15/30
# 782/782 [==============================] - 178s 228ms/step - loss: 0.9517 - accuracy: 0.7149
# Epoch 16/30
# 782/782 [==============================] - 178s 228ms/step - loss: 0.8760 - accuracy: 0.7337
# Epoch 17/30
# 782/782 [==============================] - 179s 228ms/step - loss: 0.8047 - accuracy: 0.7548
# Epoch 18/30
# 782/782 [==============================] - 178s 228ms/step - loss: 0.7349 - accuracy: 0.7750
# Epoch 19/30
# 782/782 [==============================] - 178s 228ms/step - loss: 0.6786 - accuracy: 0.7877
# Epoch 20/30
# 782/782 [==============================] - 179s 228ms/step - loss: 0.6158 - accuracy: 0.8066
# Epoch 21/30
# 782/782 [==============================] - 178s 228ms/step - loss: 0.5632 - accuracy: 0.8223
# Epoch 22/30
# 782/782 [==============================] - 179s 228ms/step - loss: 0.5181 - accuracy: 0.8351
# Epoch 23/30
# 782/782 [==============================] - 179s 228ms/step - loss: 0.4747 - accuracy: 0.8471
# Epoch 24/30
# 782/782 [==============================] - 178s 228ms/step - loss: 0.4380 - accuracy: 0.8607
# Epoch 25/30
# 782/782 [==============================] - 178s 228ms/step - loss: 0.4025 - accuracy: 0.8703
# Epoch 26/30
# 782/782 [==============================] - 178s 228ms/step - loss: 0.3708 - accuracy: 0.8792
# Epoch 27/30
# 782/782 [==============================] - 179s 228ms/step - loss: 0.3468 - accuracy: 0.8892
# Epoch 28/30
# 782/782 [==============================] - 179s 229ms/step - loss: 0.3166 - accuracy: 0.8984
# Epoch 29/30
# 782/782 [==============================] - 178s 228ms/step - loss: 0.2945 - accuracy: 0.9045
# Epoch 30/30
# 782/782 [==============================] - 178s 227ms/step - loss: 0.2713 - accuracy: 0.9126

# %% [markdown]
# ###Training for 20 more epoches

# %%
model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), epochs=20)
# Out:
# Epoch 1/20
# 782/782 [==============================] - 177s 227ms/step - loss: 0.2751 - accuracy: 0.9104
# Epoch 2/20
# 782/782 [==============================] - 177s 226ms/step - loss: 0.2545 - accuracy: 0.9175
# Epoch 3/20
# 782/782 [==============================] - 177s 226ms/step - loss: 0.2389 - accuracy: 0.9230
# Epoch 4/20
# 782/782 [==============================] - 178s 227ms/step - loss: 0.2253 - accuracy: 0.9274
# Epoch 5/20
# 782/782 [==============================] - 177s 227ms/step - loss: 0.2121 - accuracy: 0.9326
# Epoch 6/20
# 782/782 [==============================] - 177s 227ms/step - loss: 0.2078 - accuracy: 0.9325
# Epoch 7/20
# 782/782 [==============================] - 177s 226ms/step - loss: 0.1952 - accuracy: 0.9371
# Epoch 8/20
# 782/782 [==============================] - 177s 226ms/step - loss: 0.1863 - accuracy: 0.9401
# Epoch 9/20
# 782/782 [==============================] - 177s 227ms/step - loss: 0.1784 - accuracy: 0.9424
# Epoch 10/20
# 782/782 [==============================] - 177s 227ms/step - loss: 0.1752 - accuracy: 0.9433
# Epoch 11/20
# 782/782 [==============================] - 177s 227ms/step - loss: 0.1699 - accuracy: 0.9454
# Epoch 12/20
# 782/782 [==============================] - 177s 227ms/step - loss: 0.1634 - accuracy: 0.9476
# Epoch 13/20
# 782/782 [==============================] - 177s 227ms/step - loss: 0.1470 - accuracy: 0.9526
# Epoch 14/20
# 782/782 [==============================] - 177s 227ms/step - loss: 0.1557 - accuracy: 0.9494
# Epoch 15/20
# 782/782 [==============================] - 177s 226ms/step - loss: 0.1488 - accuracy: 0.9517
# Epoch 16/20
# 782/782 [==============================] - 177s 227ms/step - loss: 0.1456 - accuracy: 0.9532
# Epoch 17/20
# 782/782 [==============================] - 177s 227ms/step - loss: 0.1400 - accuracy: 0.9539
# Epoch 18/20
# 782/782 [==============================] - 177s 227ms/step - loss: 0.1338 - accuracy: 0.9563
# Epoch 19/20
# 782/782 [==============================] - 177s 226ms/step - loss: 0.1254 - accuracy: 0.9592
# Epoch 20/20
# 782/782 [==============================] - 177s 226ms/step - loss: 0.1294 - accuracy: 0.9585

# %% [markdown]
# #Visualizing learning curve of model

# %%
# Logs from additional training for 20 epochs
history2 = {
    'loss': [0.2709, 0.2576, 0.2506, 0.2301, 0.2141, 0.2093, 0.1979, 0.1922, 0.1865, 0.1773, 0.1645, 0.1609, 0.1621, 0.1592, 0.1445, 0.1465, 0.1413, 0.1363, 0.1287, 0.1372],
    'accuracy': [0.9123, 0.9155, 0.9186, 0.9245, 0.9290, 0.9319, 0.9357, 0.9374, 0.9396, 0.9433, 0.9479, 0.9482, 0.9468, 0.9480, 0.9536, 0.9538, 0.9538, 0.9567, 0.9582, 0.9554]
}

# Concatenate the history data
combined_history = {
    'loss': history.history['loss'] + history2['loss'],
    'accuracy': history.history['accuracy'] + history2['accuracy']
}

# Plot loss vs epoch
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(combined_history['loss'])
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')

# Plot accuracy vs epoch
plt.subplot(1, 2, 2)
plt.plot(combined_history['accuracy'])
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.tight_layout()
plt.show()

# %% [markdown]
# #Printing Test Accuracy

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=2)

print(f'Test Accuracy: {test_accuracy*100:.2f}%')
# Out:
# 313/313 - 11s - loss: 4.6053 - accuracy: 0.0100 - 11s/epoch - 35ms/step
# Test Accuracy: 1.00%

# %% [markdown]
# #Saving the model

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
model.save('/content/gdrive/My Drive/CIFAR_100_NN_Model.h5')
model_json = model.to_json()
with open('my_model_architecture.json', 'w') as json_file:
    json_file.write(model_json)

# Save model weights to HDF5 file
model.save_weights('my_model_weights.h5')

# %%
# !ls !ls '/content/gdrive/My Drive/CIFAR_100_NN_Model.h5'
# Out:
# '/content/gdrive/My Drive/CIFAR_100_NN_Model.h5'

# %% [markdown]
# #Making Predictions

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 10s 31ms/step

# %% [markdown]
# ### Display the first few test images along with their predicted and actual classes

# %%
# Choose 10 random indices
random_indices = random.sample(range(len(x_test)), 10)

# Make predictions on the selected random test data
selected_x_test = x_test[random_indices]
selected_y_test = y_test[random_indices]
selected_predictions = model.predict(selected_x_test)

# Display the randomly selected test images along with their predicted and actual classes
plt.figure(figsize=(15, 8))
for i, idx in enumerate(random_indices):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_test[idx])

    actual_class = int(np.argmax(selected_y_test[i]))  # Assuming y_test is one-hot encoded
    predicted_class = int(np.argmax(selected_predictions[i]))

    # Check if the prediction is correct
    text_color = 'green' if actual_class == predicted_class else 'red'

    plt.title(f'Actual: {class_names[actual_class]}\nPredicted: {class_names[predicted_class]}', color=text_color)
    plt.axis('off')

plt.show()
# Out:
# 1/1 [==============================] - 0s 29ms/step
